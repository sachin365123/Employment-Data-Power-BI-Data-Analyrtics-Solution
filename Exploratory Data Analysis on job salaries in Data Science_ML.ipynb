# %%
import pandas as pd

# %%
data=pd.read_csv('ds_salaries.csv')

# %%
type(data)
# pandas-->> Series ---> Single dimensional
# panads-->> Dataframe--->> Mutdimensional
# Out:
# pandas.core.frame.DataFrame

# %%
data.sample(20)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 13           13       2020               MI              FT
# 90           90       2021               SE              FT
# 78           78       2021               MI              CT
# 546         546       2022               SE              FT
# 597         597       2022               SE              FT
# 430         430       2022               MI              FT
# 560         560       2022               SE              FT
# 292         292       2022               MI              FT
# 493         493       2022               SE              FT
# 109         109       2021               EN              FT
# 489         489       2022               EN              CT
# 185         185       2021               MI              FT
# 467         467       2022               SE              FT
# 129         129       2021               SE              FT
# 33           33       2020               MI              FT
# ...

# %%
data.tail(20)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 587         587       2022               SE              FT
# 588         588       2022               SE              FT
# 589         589       2022               SE              FT
# 590         590       2022               SE              FT
# 591         591       2022               SE              FT
# 592         592       2022               SE              FT
# 593         593       2022               SE              FT
# 594         594       2022               SE              FT
# 595         595       2022               SE              FT
# 596         596       2022               SE              FT
# 597         597       2022               SE              FT
# 598         598       2022               MI              FT
# 599         599       2022               MI              FT
# 600         600       2022               EN              FT
# 601         601       2022               EN              FT
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
data.shape
# Out:
# (607, 12)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
data['employee_residence'].value_counts()
# Out:
# employee_residence
# US    332
# GB     44
# IN     30
# CA     29
# DE     25
# FR     18
# ES     15
# GR     13
# JP      7
# PT      6
# BR      6
# PK      6
# NL      5
# PL      4
# IT      4
# RU      4
# AE      3
# AT      3
# VN      3
# TR      3
# AU      3
# RO      2
# BE      2
# SG      2
# SI      2
# DK      2
# HU      2
# NG      2
# MX      2
# BO      1
# MY      1
# TN      1
# IE      1
# DZ      1
# AR      1
# CZ      1
# JE      1
# LU      1
# PR      1
# RS      1
# EE      1
# CL      1
# HK      1
# KE      1
# MD      1
# CO      1
# IR      1
# CN      1
# MT      1
# UA      1
# IQ      1
# HN      1
# BG      1
# HR      1
# PH      1
# NZ      1
# CH      1
# Name: count, dtype: int64

# %%
data[]

# %%
data.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
data.drop(['salary', 'salary_currency'],axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary_in_usd', 'employee_residence', 'remote_ratio',
#        'company_location', 'company_size'],
#       dtype='object')

# %%
data['experience_level'].unique()
# Out:
# array(['MI', 'SE', 'EN', 'EX'], dtype=object)

# %%
data.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0          79833                 DE             0               DE
# 1         260000                 JP             0               JP
# 2         109024                 GB            50               GB
# 3          20000                 HN             0               HN
# 4         150000                 US            50               US
#
#   company_size
# 0            L
# 1            S
# 2            M
# 3            S
# 4            L

# %%
data['experience_level']=data['experience_level'].map({'MI':'MID','SE':'Senior','EN':'Engineer','EX':'Executed'})

# %%
data.head(20)
# Out:
#     work_year experience_level employment_type                   job_title  \
# 0        2020              MID              FT              Data Scientist
# 1        2020           Senior              FT  Machine Learning Scientist
# 2        2020           Senior              FT           Big Data Engineer
# 3        2020              MID              FT        Product Data Analyst
# 4        2020           Senior              FT   Machine Learning Engineer
# 5        2020         Engineer              FT                Data Analyst
# 6        2020           Senior              FT         Lead Data Scientist
# 7        2020              MID              FT              Data Scientist
# 8        2020              MID              FT       Business Data Analyst
# 9        2020           Senior              FT          Lead Data Engineer
# 10       2020         Engineer              FT              Data Scientist
# ...

# %%
# Example 2: Convert temperatures from Celsius to Fahrenheit
list1 = [25, 30, 15, 10,15,12,78,12]

# Using a named function
def celsius_to_techlang(celsius):
    celsius=+10
    return (celsius * 19/50) + 320

fahrenheit_temperatures = list(map(celsius_to_techlang, list1))
print(fahrenheit_temperatures)  # Output: [77.0, 86.0, 59.0, 50.0]
# Out:
# [323.8, 323.8, 323.8, 323.8, 323.8, 323.8, 323.8, 323.8]

# %%
# Example 1: Square of numbers using map()
numbers = [1, 2, 3, 4, 5,7,9,11,20,148,250]
# 1, 4, 9, 16, 25

# Using a lambda function
squared_numbers = list(map(lambda x: x+20, numbers))
print(squared_numbers)  # Output: [1, 4, 9, 16, 25]
# Out:
# [21, 22, 23, 24, 25, 27, 29, 31, 40, 168, 270]

# %%
data.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 42

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (565, 9)

# %%
data['salary_in_usd'].describe()
# Out:
# count       565.000000
# mean     110610.343363
# std       72280.702792
# min        2859.000000
# 25%       60757.000000
# 50%      100000.000000
# 75%      150000.000000
# max      600000.000000
# Name: salary_in_usd, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=data,x='salary_in_usd')
plt.show()

# %%
Infosys Employees: 10 LPA, 8 LPA, 6.5 LPA, 5 LPA, 8.2 LPA, 29 LPA GM, 6 LPA, 5.2 LPA, 52 LPA CEO
    Class 3, 4th
    Executive or Class 1 , Higher authority

# %%
data_outlier=data[data['salary_in_usd']>300000]

# %%
data_outlier.shape
# Out:
# (10, 9)

# %%
data=data[~(data['salary_in_usd']>300000)]

# %%
data.shape
# Out:
# (555, 9)

# %%
## Below function will plot countplot for the provided feature
def count_plot(feature):
    plt.figure(figsize=(15,5))
    ax = sns.countplot(data=data,x=feature)
    for p in ax.patches:
        ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+2))
        plt.xticks(rotation=90)
        plt.show()

# %%
count_plot('work_year')

# %%
count_plot('experience_level')

# %%
count_plot('employment_type')

# %%
count_plot('job_title')

# %% [markdown]
# # Multivarient analysis

# %%
# Ques 1. Which job title earns highest salary ?

# %%
# Function to plot box plot
def box_plot(x,y,data,title):
    plt.figure(figsize=(10,8))
    sals_mean = data.groupby([x])[y].mean();
 
 #print(sals)
    ax = sns.boxplot(data=data,y=y,x = x)
 
    vertical_offset_mean = data[y].median() * 0.05 # offset from median for display
    vertical_offset_max = data[y].max() * 0.05
 
# 1. Which job title earns highest salary ?
    for i,xtick in enumerate(ax.get_xticklabels(which='major')):
        #print(xtick.get_text())
        ax.text(i,sals_mean[xtick.get_text()] + vertical_offset_mean,sals_mean[xtick.get_horizontalalignment='center',size='small',color='w',weight='semibold')
    ax.set_title(title) 
    plt.show()
# Out:
#   File "C:\Users\Sachin\AppData\Local\Temp\ipykernel_9564\660881456.py", line 15
#     ax.text(i,sals_mean[xtick.get_text()] + vertical_offset_mean,sals_mean[xtick.get_horizontalalignment='center',size='small',color='w',weight='semibold')
#                                                                                                         ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Function to plot box plot
def box_plot(x, y, data, title):
    plt.figure(figsize=(10, 8))
    sals_mean = data.groupby([x])[y].mean()

    ax = sns.boxplot(data=data, y=y, x=x)

    vertical_offset_mean = data[y].median() * 0.05
    vertical_offset_max = data[y].max() * 0.05

    for i, xtick in enumerate(ax.get_xticklabels(which='major')):
        ax.text(i, sals_mean[xtick.get_text()] + vertical_offset_mean, sals_mean[xtick.get_text()],
                horizontalalignment='center', size='small', color='w', weight='semibold')

    ax.set_title(title)
    plt.show()

# %%
# Function to plot bar plot
def bar_plot(feature,data,title):
    data = data.groupby(feature)['salary_in_usd'].mean()
    plt.figure(figsize=(12,16))
    ax = sns.barplot(x=data.values, y=data.index,color='pink')
    for i, v in enumerate(data.values):
        ax.annotate(str(v), xy=(v,i), va='center')
        ax.set_xlabel("salary")
        ax.set_ylabel(feature)
        ax.set_title(title)
        plt.show()

# %%
bar_plot('job_title',data,'Avaerage Salary for each job title')

# %%
# Ques 1. Which job title earns highest salary ?
# Answer: Principal Data Engineer

# %%
# Ques 2. What is the average salary for each experience level ?

# %%
box_plot('experience_level','salary_in_usd',data,'Experience level vs Salary')

# %%
# Ques 3 What is average salary for company size Large, Small, and Medium?

# %%
box_plot('company_size','salary_in_usd',data,'Company size vs Salary')

# %%
Ques 4 Does people working Full time earns more than contract base employess?

# %%
box_plot('employment_type','salary_in_usd',data,'Employee type vs Salary')

# %%
data[(data['employment_type']=='CT')&(data['salary_in_usd']>250000)]
# Out:
#     work_year experience_level employment_type    job_title  salary_in_usd  \
# 78       2021               MI              CT  ML Engineer         270000
#
#    employee_residence  remote_ratio company_location company_size
# 78                 US           100               US            L

# %%
data=data[~((data['employment_type']=='CT')&(data['salary_in_usd']>250000))]

# %%
data[(data['employment_type']=='CT')&(data['salary_in_usd']>250000)]
# Out:
# Empty DataFrame
# Columns: [work_year, experience_level, employment_type, job_title, salary_in_usd, employee_residence, remote_ratio, company_location, company_size]
# Index: []

# %%
box_plot('employment_type','salary_in_usd',data,'Employee type vs Salary')

# %%
Ques 5 Is salary less for Employees working remotely than who comes to office?

# %%
box_plot('remote_ratio','salary_in_usd',data,'Remote ration Vs Salary')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5940\2406172992.py in <module>
# ...

# %%
Question which country pays more to the employees?

# %%
bar_plot('company_location',data,'Average Salary va each country')

# %%
# Russia and US

# %%
# Question 7: what is the highest earning job in highest paying countries?

# %%
data_RU=data[data['company_location']=='RU']
data_US=data[data['company_location']=='US']
bar_plot('job_title',data_RU,"Avg salary for each job title in Russia")

# %%
bar_plot('job_title',data_US,"Avg salary for each job title in USA")

# %%
Question 8: What is avg salary for highest earning job titles working at expert level?

# %%
data_expert=data[data['experience_level']=='EX']

# %%
data_expert.shape
# Out:
# (22, 9)

# %%
bar_plot('job_title',data_expert,"Avg salary for each job title with expe level")

# %%
# Head of Data
# Data Engineer
